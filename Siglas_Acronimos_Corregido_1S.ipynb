# %% [markdown]
# <a href="https://colab.research.google.com/github/alexandergribenchenko/iScribo/blob/main/Siglas_Acronimos_Corregido_1S.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
matriz_reemplazos = pd.read_excel('Siglas_Acronimos_Corregido_1S.xlsx', header=None)

# %%
matriz_reemplazos
# Out:
#                     0  ...                                                  2
# 0        C.I.D.D.M.-2  ...  Clasificación Internacional del Funcionamient...
# 1   C. I. D. D. M. -2  ...  Clasificación Internacional del Funcionamient...
# 2        C I D D M -2  ...  Clasificación Internacional del Funcionamient...
# 3             Ciddm-2  ...  Clasificación Internacional del Funcionamient...
# 4             ciddm-2  ...  Clasificación Internacional del Funcionamient...
# 5        c.i.d.d.m.-2  ...  Clasificación Internacional del Funcionamient...
# 6   c. i. d. d. m. -2  ...  Clasificación Internacional del Funcionamient...
# 7        c i d d m -2  ...  Clasificación Internacional del Funcionamient...
# 8            Ciddm-2.  ...  Clasificación Internacional del Funcionamient...
# 9            ciddm-2.  ...  Clasificación Internacional del Funcionamient...
# 10               G.-5  ...                                 Grupo de los Cinco
# 11              G. -5  ...                                 Grupo de los Cinco
# 12               G -5  ...                                 Grupo de los Cinco
# 13               G-5.  ...                                 Grupo de los Cinco
# 14                g-5  ...                                 Grupo de los Cinco
# 15               g.-5  ...                                 Grupo de los Cinco
# 16              g. -5  ...                                 Grupo de los Cinco
# 17               g -5  ...                                 Grupo de los Cinco
# 18               g-5.  ...                                 Grupo de los Cinco
# 19               G.-7  ...                                 Grupo de los Siete
# 20              G. -7  ...                                 Grupo de los Siete
# 21               G -7  ...                                 Grupo de los Siete
# 22               G-7.  ...                                 Grupo de los Siete
# 23                g-7  ...                                 Grupo de los Siete
# 24               g.-7  ...                                 Grupo de los Siete
# 25              g. -7  ...                                 Grupo de los Siete
# 26               g -7  ...                                 Grupo de los Siete
# 27               g-7.  ...                                 Grupo de los Siete
# 28              G.-10  ...                                  Grupo de los Diez
# 29             G. -10  ...                                  Grupo de los Diez
# 30              G -10  ...                                  Grupo de los Diez
# 31              G-10.  ...                                  Grupo de los Diez
# 32               g-10  ...                                  Grupo de los Diez
# 33              g.-10  ...                                  Grupo de los Diez
# 34             g. -10  ...                                  Grupo de los Diez
# 35              g -10  ...                                  Grupo de los Diez
# 36              G-10.  ...                                  Grupo de los Diez
# 37              G.-20  ...                                    Grupo de los 20
# 38             G. -20  ...                                    Grupo de los 20
# 39              G -20  ...                                    Grupo de los 20
# 40              G-20.  ...                                    Grupo de los 20
# 41               g-20  ...                                    Grupo de los 20
# 42              g.-20  ...                                    Grupo de los 20
# 43             g. -20  ...                                    Grupo de los 20
# 44              g -20  ...                                    Grupo de los 20
# 45              g-20.  ...                                    Grupo de los 20
#
# [46 rows x 3 columns]

# %%
# matriz_reemplazos = matriz_reemplazos.applymap(lambda x: x.replace('–','-'))

# %%
# matriz_reemplazos[1] = matriz_reemplazos[1].apply(lambda x: x.replace(' /// ','-'))

# %%
matriz_reemplazos
# Out:
#                     0  ...                                                  2
# 0        C.I.D.D.M.-2  ...  Clasificación Internacional del Funcionamient...
# 1   C. I. D. D. M. -2  ...  Clasificación Internacional del Funcionamient...
# 2        C I D D M -2  ...  Clasificación Internacional del Funcionamient...
# 3             Ciddm-2  ...  Clasificación Internacional del Funcionamient...
# 4             ciddm-2  ...  Clasificación Internacional del Funcionamient...
# 5        c.i.d.d.m.-2  ...  Clasificación Internacional del Funcionamient...
# 6   c. i. d. d. m. -2  ...  Clasificación Internacional del Funcionamient...
# 7        c i d d m -2  ...  Clasificación Internacional del Funcionamient...
# 8            Ciddm-2.  ...  Clasificación Internacional del Funcionamient...
# 9            ciddm-2.  ...  Clasificación Internacional del Funcionamient...
# 10               G.-5  ...                                 Grupo de los Cinco
# 11              G. -5  ...                                 Grupo de los Cinco
# 12               G -5  ...                                 Grupo de los Cinco
# 13               G-5.  ...                                 Grupo de los Cinco
# 14                g-5  ...                                 Grupo de los Cinco
# 15               g.-5  ...                                 Grupo de los Cinco
# 16              g. -5  ...                                 Grupo de los Cinco
# 17               g -5  ...                                 Grupo de los Cinco
# 18               g-5.  ...                                 Grupo de los Cinco
# 19               G.-7  ...                                 Grupo de los Siete
# 20              G. -7  ...                                 Grupo de los Siete
# 21               G -7  ...                                 Grupo de los Siete
# 22               G-7.  ...                                 Grupo de los Siete
# 23                g-7  ...                                 Grupo de los Siete
# 24               g.-7  ...                                 Grupo de los Siete
# 25              g. -7  ...                                 Grupo de los Siete
# 26               g -7  ...                                 Grupo de los Siete
# 27               g-7.  ...                                 Grupo de los Siete
# 28              G.-10  ...                                  Grupo de los Diez
# 29             G. -10  ...                                  Grupo de los Diez
# 30              G -10  ...                                  Grupo de los Diez
# 31              G-10.  ...                                  Grupo de los Diez
# 32               g-10  ...                                  Grupo de los Diez
# 33              g.-10  ...                                  Grupo de los Diez
# 34             g. -10  ...                                  Grupo de los Diez
# 35              g -10  ...                                  Grupo de los Diez
# 36              G-10.  ...                                  Grupo de los Diez
# 37              G.-20  ...                                    Grupo de los 20
# 38             G. -20  ...                                    Grupo de los 20
# 39              G -20  ...                                    Grupo de los 20
# 40              G-20.  ...                                    Grupo de los 20
# 41               g-20  ...                                    Grupo de los 20
# 42              g.-20  ...                                    Grupo de los 20
# 43             g. -20  ...                                    Grupo de los 20
# 44              g -20  ...                                    Grupo de los 20
# 45              g-20.  ...                                    Grupo de los 20
#
# [46 rows x 3 columns]

# %%
    path_format = 'patrones_xml_base.txt'
    #path_excel = path_excel
    path_output = 'salida.txt'

    handler = open(path_format)
    contenido = handler.read()

# %%
    salida=''
    for index in range(len(matriz_reemplazos)):
        # Entradas sin casos diferentes
        comment_replace = 'comment'
        id_replace = matriz_reemplazos[0][index] + '/' + matriz_reemplazos[1][index]
        name_replace = id_replace
        message_replace = matriz_reemplazos[2][index]

        # Reemplazos para entradas sin casos diferentes
        contenido_temp = contenido.replace("comment_replace", comment_replace)
        contenido_temp = contenido_temp.replace("id_replace", id_replace)
        contenido_temp = contenido_temp.replace("name_replace", name_replace)
        contenido_temp = contenido_temp.replace("message_replace", message_replace)

        # Entradas con casos diferentes
        token_replace_in = matriz_reemplazos[0][index]
        token_replace=''
        for x in token_replace_in.split():
            token_replace+='<token>'+x+'</token>'+'\n'+'  '
        token_replace = token_replace[:-3]

        suggestion_replace_in = matriz_reemplazos[1][index]
        suggestion_replace = '<suggestion>'+suggestion_replace_in+'</suggestion>'

        # Reemplazos para entradas con casos diferentes
        contenido_temp = contenido_temp.replace("<token>token_replace</token>", token_replace)
        contenido_temp = contenido_temp.replace("<suggestion>suggestion_replace</suggestion>", suggestion_replace)

        # Salida que concatena las salidas para cada registro
        salida+=contenido_temp+'\n\n'

# %%
print(salida)
# Out:
# <!--comment-->
# <rule id="C.I.D.D.M.-2/CIDDM-2" name="C.I.D.D.M.-2/CIDDM-2">
#  <pattern>
#   <token>C.I.D.D.M.-2</token>
#  </pattern>
#  <message>Clasificación Internacional del Funcionamiento y la Discapacidad</message>
#  <suggestion>CIDDM-2</suggestion>
# </rule>
#
# <!--comment-->
# <rule id="C. I. D. D. M. -2/CIDDM-2" name="C. I. D. D. M. -2/CIDDM-2">
#  <pattern>
#   <token>C.</token>
#   <token>I.</token>
#   <token>D.</token>
#   <token>D.</token>
#   <token>M.</token>
#   <token>-2</token>
#  </pattern>
#  <message>Clasificación Internacional del Funcionamiento y la Discapacidad</message>
#  <suggestion>CIDDM-2</suggestion>
# </rule>
#
# <!--comment-->
# <rule id="C I D D M -2/CIDDM-2" name="C I D D M -2/CIDDM-2">
#  <pattern>
#   <token>C</token>
#   <token>I</token>
#   <token>D</token>
#   <token>D</token>
#   <token>M</token>
#   <token>-2</token>
#  </pattern>
#  <message>Clasificación Internacional del Funcionamiento y la Discapacidad</message>
#  <suggestion>CIDDM-2</suggestion>
# </rule>
#
# <!--comment-->
# <rule id="Ciddm-2/CIDDM-2" name="Ciddm-2/CIDDM-2">
#  <pattern>
#   <token>Ciddm-2</token>
#  </pattern>
#  <message>Clasificación Internacional del Funcionamiento y la Discapacidad</message>
#  <suggestion>CIDDM-2</suggestion>
# </rule>
#
# <!--comment-->
# <rule id="ciddm-2/CIDDM-2" name="ciddm-2/CIDDM-2">
#  <pattern>
#   <token>ciddm-2</token>
#  </pattern>
#  <message>Clasificación Internacional del Funcionamiento y la Discapacidad</message>
#  <suggestion>CIDDM-2</suggestion>
# </rule>
#
# <!--comment-->
# <rule id="c.i.d.d.m.-2/CIDDM-2" name="c.i.d.d.m.-2/CIDDM-2">
#  <pattern>
#   <token>c.i.d.d.m.-2</token>
#  </pattern>
#  <message>Clasificación Internacional del Funcionamiento y la Discapacidad</message>
#  <suggestion>CIDDM-2</suggestion>
# </rule>
#
# <!--comment-->
# <rule id="c. i. d. d. m. -2/CIDDM-2" name="c. i. d. d. m. -2/CIDDM-2">
#  <pattern>
#   <token>c.</token>
#   <token>i.</token>
#   <token>d.</token>
#   <token>d.</token>
#   <token>m.</token>
#   <token>-2</token>
#  </pattern>
#  <message>Clasificación Internacional del Funcionamiento y la Discapacidad</message>
#  <suggestion>CIDDM-2</suggestion>
# </rule>
#
# <!--comment-->
# <rule id="c i d d m -2/CIDDM-2" name="c i d d m -2/CIDDM-2">
#  <pattern>
#   <token>c</token>
#   <token>i</token>
#   <token>d</token>
#   <token>d</token>
#   <token>m</token>
#   <token>-2</token>
#  </pattern>
#  <message>Clasificación Internacional del Funcionamiento y la Discapacidad</message>
#  <suggestion>CIDDM-2</suggestion>
# </rule>
#
# <!--comment-->
# <rule id="Ciddm-2./CIDDM-2" name="Ciddm-2./CIDDM-2">
#  <pattern>
#   <token>Ciddm-2.</token>
#  </pattern>
#  <message>Clasificación Internacional del Funcionamiento y la Discapacidad</message>
#  <suggestion>CIDDM-2</suggestion>
# </rule>
#
# <!--comment-->
# <rule id="ciddm-2./CIDDM-2" name="ciddm-2./CIDDM-2">
#  <pattern>
#   <token>ciddm-2.</token>
#  </pattern>
#  <message>Clasificación Internacional del Funcionamiento y la Discapacidad</message>
#  <suggestion>CIDDM-2</suggestion>
# </rule>
#
# <!--comment-->
# <rule id="G.-5/G-5" name="G.-5/G-5">
#  <pattern>
#   <token>G.-5</token>
#  </pattern>
#  <message>Grupo de los Cinco</message>
#  <suggestion>G-5</suggestion>
# </rule>
#
# <!--comment-->
# <rule id="G. -5/G-5" name="G. -5/G-5">
#  <pattern>
#   <token>G.</token>
#   <token>-5</token>
#  </pattern>
#  <message>Grupo de los Cinco</message>
#  <suggestion>G-5</suggestion>
# </rule>
#
# <!--comment-->
# <rule id="G -5/G-5" name="G -5/G-5">
#  <pattern>
#   <token>G</token>
#   <token>-5</token>
#  </pattern>
#  <message>Grupo de los Cinco</message>
#  <suggestion>G-5</suggestion>
# </rule>
#
# <!--comment-->
# <rule id="G-5./G-5" name="G-5./G-5">
#  <pattern>
#   <token>G-5.</token>
#  </pattern>
#  <message>Grupo de los Cinco</message>
#  <suggestion>G-5</suggestion>
# </rule>
#
# <!--comment-->
# <rule id="g-5/G-5" name="g-5/G-5">
#  <pattern>
#   <token>g-5</token>
#  </pattern>
#  <message>Grupo de los Cinco</message>
#  <suggestion>G-5</suggestion>
# </rule>
#
# <!--comment-->
# <rule id="g.-5/G-5" name="g.-5/G-5">
#  <pattern>
#   <token>g.-5</token>
#  </pattern>
#  <message>Grupo de los Cinco</message>
#  <suggestion>G-5</suggestion>
# </rule>
#
# <!--comment-->
# <rule id="g. -5/G-5" name="g. -5/G-5">
#  <pattern>
#   <token>g.</token>
#   <token>-5</token>
#  </pattern>
#  <message>Grupo de los Cinco</message>
#  <suggestion>G-5</suggestion>
# </rule>
#
# <!--comment-->
# <rule id="g -5/G-5" name="g -5/G-5">
#  <pattern>
#   <token>g</token>
#   <token>-5</token>
#  </pattern>
#  <message>Grupo de los Cinco</message>
#  <suggestion>G-5</suggestion>
# </rule>
#
# <!--comment-->
# <rule id="g-5./G-5" name="g-5./G-5">
#  <pattern>
#   <token>g-5.</token>
#  </pattern>
#  <message>Grupo de los Cinco</message>
#  <suggestion>G-5</suggestion>
# </rule>
#
# <!--comment-->
# <rule id="G.-7/G-7" name="G.-7/G-7">
#  <pattern>
#   <token>G.-7</token>
#  </pattern>
#  <message>Grupo de los Siete</message>
#  <suggestion>G-7</suggestion>
# </rule>
#
# <!--comment-->
# <rule id="G. -7/G-7" name="G. -7/G-7">
#  <pattern>
#   <token>G.</token>
#   <token>-7</token>
#  </pattern>
#  <message>Grupo de los Siete</message>
#  <suggestion>G-7</suggestion>
# </rule>
#
# <!--comment-->
# <rule id="G -7/G-7" name="G -7/G-7">
#  <pattern>
#   <token>G</token>
#   <token>-7</token>
#  </pattern>
#  <message>Grupo de los Siete</message>
#  <suggestion>G-7</suggestion>
# </rule>
#
# <!--comment-->
# <rule id="G-7./G-7" name="G-7./G-7">
#  <pattern>
#   <token>G-7.</token>
#  </pattern>
#  <message>Grupo de los Siete</message>
#  <suggestion>G-7</suggestion>
# </rule>
#
# <!--comment-->
# <rule id="g-7/G-7" name="g-7/G-7">
#  <pattern>
#   <token>g-7</token>
#  </pattern>
#  <message>Grupo de los Siete</message>
#  <suggestion>G-7</suggestion>
# </rule>
#
# <!--comment-->
# <rule id="g.-7/G-7" name="g.-7/G-7">
#  <pattern>
#   <token>g.-7</token>
#  </pattern>
#  <message>Grupo de los Siete</message>
#  <suggestion>G-7</suggestion>
# </rule>
#
# <!--comment-->
# <rule id="g. -7/G-7" name="g. -7/G-7">
#  <pattern>
#   <token>g.</token>
#   <token>-7</token>
#  </pattern>
#  <message>Grupo de los Siete</message>
#  <suggestion>G-7</suggestion>
# </rule>
#
# <!--comment-->
# <rule id="g -7/G-7" name="g -7/G-7">
#  <pattern>
#   <token>g</token>
#   <token>-7</token>
#  </pattern>
#  <message>Grupo de los Siete</message>
#  <suggestion>G-7</suggestion>
# </rule>
#
# <!--comment-->
# <rule id="g-7./G-7" name="g-7./G-7">
#  <pattern>
#   <token>g-7.</token>
#  </pattern>
#  <message>Grupo de los Siete</message>
#  <suggestion>G-7</suggestion>
# </rule>
#
# <!--comment-->
# <rule id="G.-10/G-10" name="G.-10/G-10">
#  <pattern>
#   <token>G.-10</token>
#  </pattern>
#  <message>Grupo de los Diez</message>
#  <suggestion>G-10</suggestion>
# </rule>
#
# <!--comment-->
# <rule id="G. -10/G-10" name="G. -10/G-10">
#  <pattern>
#   <token>G.</token>
#   <token>-10</token>
#  </pattern>
#  <message>Grupo de los Diez</message>
#  <suggestion>G-10</suggestion>
# </rule>
#
# <!--comment-->
# <rule id="G -10/G-10" name="G -10/G-10">
#  <pattern>
#   <token>G</token>
#   <token>-10</token>
#  </pattern>
#  <message>Grupo de los Diez</message>
#  <suggestion>G-10</suggestion>
# </rule>
#
# <!--comment-->
# <rule id="G-10./G-10" name="G-10./G-10">
#  <pattern>
#   <token>G-10.</token>
#  </pattern>
#  <message>Grupo de los Diez</message>
#  <suggestion>G-10</suggestion>
# </rule>
#
# <!--comment-->
# <rule id="g-10/G-10" name="g-10/G-10">
#  <pattern>
#   <token>g-10</token>
#  </pattern>
#  <message>Grupo de los Diez</message>
#  <suggestion>G-10</suggestion>
# </rule>
#
# <!--comment-->
# <rule id="g.-10/G-10" name="g.-10/G-10">
#  <pattern>
#   <token>g.-10</token>
#  </pattern>
#  <message>Grupo de los Diez</message>
#  <suggestion>G-10</suggestion>
# </rule>
#
# <!--comment-->
# <rule id="g. -10/G-10" name="g. -10/G-10">
#  <pattern>
#   <token>g.</token>
#   <token>-10</token>
#  </pattern>
#  <message>Grupo de los Diez</message>
#  <suggestion>G-10</suggestion>
# </rule>
#
# <!--comment-->
# <rule id="g -10/G-10" name="g -10/G-10">
#  <pattern>
#   <token>g</token>
#   <token>-10</token>
#  </pattern>
#  <message>Grupo de los Diez</message>
#  <suggestion>G-10</suggestion>
# </rule>
#
# <!--comment-->
# <rule id="G-10./G-10" name="G-10./G-10">
#  <pattern>
#   <token>G-10.</token>
#  </pattern>
#  <message>Grupo de los Diez</message>
#  <suggestion>G-10</suggestion>
# </rule>
#
# <!--comment-->
# <rule id="G.-20/G-20" name="G.-20/G-20">
#  <pattern>
#   <token>G.-20</token>
#  </pattern>
#  <message>Grupo de los 20</message>
#  <suggestion>G-20</suggestion>
# </rule>
#
# <!--comment-->
# <rule id="G. -20/G-20" name="G. -20/G-20">
#  <pattern>
#   <token>G.</token>
#   <token>-20</token>
#  </pattern>
#  <message>Grupo de los 20</message>
#  <suggestion>G-20</suggestion>
# </rule>
#
# <!--comment-->
# <rule id="G -20/G-20" name="G -20/G-20">
#  <pattern>
#   <token>G</token>
#   <token>-20</token>
#  </pattern>
#  <message>Grupo de los 20</message>
#  <suggestion>G-20</suggestion>
# </rule>
#
# <!--comment-->
# <rule id="G-20./G-20" name="G-20./G-20">
#  <pattern>
#   <token>G-20.</token>
#  </pattern>
#  <message>Grupo de los 20</message>
#  <suggestion>G-20</suggestion>
# </rule>
#
# <!--comment-->
# <rule id="g-20/G-20" name="g-20/G-20">
#  <pattern>
#   <token>g-20</token>
#  </pattern>
#  <message>Grupo de los 20</message>
#  <suggestion>G-20</suggestion>
# </rule>
#
# <!--comment-->
# <rule id="g.-20/G-20" name="g.-20/G-20">
#  <pattern>
#   <token>g.-20</token>
#  </pattern>
#  <message>Grupo de los 20</message>
#  <suggestion>G-20</suggestion>
# </rule>
#
# <!--comment-->
# <rule id="g. -20/G-20" name="g. -20/G-20">
#  <pattern>
#   <token>g.</token>
#   <token>-20</token>
#  </pattern>
#  <message>Grupo de los 20</message>
#  <suggestion>G-20</suggestion>
# </rule>
#
# <!--comment-->
# <rule id="g -20/G-20" name="g -20/G-20">
#  <pattern>
#   <token>g</token>
#   <token>-20</token>
#  </pattern>
#  <message>Grupo de los 20</message>
#  <suggestion>G-20</suggestion>
# </rule>
#
# <!--comment-->
# <rule id="g-20./G-20" name="g-20./G-20">
#  <pattern>
#   <token>g-20.</token>
#  </pattern>
#  <message>Grupo de los 20</message>
#  <suggestion>G-20</suggestion>
# </rule>

# %%
text_file = open(path_output, "w")
text_file.write(salida)
text_file.close()
